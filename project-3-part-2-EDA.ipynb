# %%
import pandas as pd

# %%
year2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
year2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')

# %%
year2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ...     revenue  runtime  \
# 0       NaN               NaN              NaN  ...         NaN      NaN
# 1   62127.0                en  The Fantasticks  ...         0.0     86.0
# 2  110977.0                en    For the Cause  ...         0.0    100.0
# 3  442869.0                hi             Gang  ...         0.0    152.0
# 4     843.0                cn             花樣年華  ...  12854953.0     99.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                              tagline                 title  \
# 0                                                NaN                   NaN
# 1      Try to remember the first time magic happened       The Fantasticks
# 2       The ultimate showdown on a forbidden planet.         For the Cause
# 3                                                NaN                  Gang
# 4  Feel the heat, keep the feeling burning, let t...  In the Mood for Love
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         5.500       22.0           NaN
# 2    0.0         5.100        8.0           NaN
# 3    0.0         4.000        1.0           NaN
# 4    0.0         8.114     2191.0            PG
#
# [5 rows x 26 columns]

# %%
year2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1234 non-null   object
#  1   adult                  1233 non-null   float64
#  2   backdrop_path          679 non-null    object
#  3   belongs_to_collection  113 non-null    object
#  4   budget                 1233 non-null   float64
#  5   genres                 1233 non-null   object
#  6   homepage               64 non-null     object
#  7   id                     1233 non-null   float64
#  8   original_language      1233 non-null   object
#  9   original_title         1233 non-null   object
#  10  overview               1212 non-null   object
#  11  popularity             1233 non-null   float64
#  12  poster_path            1111 non-null   object
#  13  production_companies   1233 non-null   object
#  14  production_countries   1233 non-null   object
#  15  release_date           1226 non-null   object
#  16  revenue                1233 non-null   float64
#  17  runtime                1233 non-null   float64
#  18  spoken_languages       1233 non-null   object
#  19  status                 1233 non-null   object
#  20  tagline                547 non-null    object
#  21  title                  1233 non-null   object
#  22  video                  1233 non-null   float64
#  23  vote_average           1233 non-null   float64
#  24  vote_count             1233 non-null   float64
#  25  certification          391 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 250.8+ KB

# %%
year2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
#          id original_language         original_title  ...     revenue  \
# 0       NaN               NaN                    NaN  ...         NaN
# 1   11232.0                en         Kate & Leopold  ...  76019048.0
# 2  151007.0                en       The Silent Force  ...         0.0
# 3   10696.0                en                Glitter  ...   5271666.0
# 4   17140.0                en  The Attic Expeditions  ...         0.0
#
#    runtime                                   spoken_languages    status  \
# 0      NaN                                                NaN       NaN
# 1    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     90.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3    104.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4    100.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline                  title  \
# 0                                                NaN                    NaN
# 1  If they lived in the same century, they'd be p...         Kate & Leopold
# 2  They left him for dead... They should have fin...       The Silent Force
# 3   In music she found her dream, her love, herself.                Glitter
# 4  His search for peace of mind... will leave his...  The Attic Expeditions
#
#    video  vote_average vote_count certification
# 0    NaN           NaN        NaN           NaN
# 1    0.0         6.326     1187.0         PG-13
# 2    0.0         5.000        3.0           NaN
# 3    0.0         4.536      124.0         PG-13
# 4    0.0         5.100       29.0             R
#
# [5 rows x 26 columns]

# %%
year2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330 entries, 0 to 1329
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1330 non-null   object
#  1   adult                  1329 non-null   float64
#  2   backdrop_path          715 non-null    object
#  3   belongs_to_collection  92 non-null     object
#  4   budget                 1329 non-null   float64
#  5   genres                 1329 non-null   object
#  6   homepage               109 non-null    object
#  7   id                     1329 non-null   float64
#  8   original_language      1329 non-null   object
#  9   original_title         1329 non-null   object
#  10  overview               1300 non-null   object
#  11  popularity             1329 non-null   float64
#  12  poster_path            1194 non-null   object
#  13  production_companies   1329 non-null   object
#  14  production_countries   1329 non-null   object
#  15  release_date           1318 non-null   object
#  16  revenue                1329 non-null   float64
#  17  runtime                1329 non-null   float64
#  18  spoken_languages       1329 non-null   object
#  19  status                 1329 non-null   object
#  20  tagline                552 non-null    object
#  21  title                  1329 non-null   object
#  22  video                  1329 non-null   float64
#  23  vote_average           1329 non-null   float64
#  24  vote_count             1329 non-null   float64
#  25  certification          424 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 270.3+ KB

# %%
df = pd.concat([year2000, year2001], ignore_index=True)
df.tail()
# Out:
#         imdb_id                adult backdrop_path belongs_to_collection  \
# 2559  tt7797670                 0.00           NaN                   NaN
# 2560  tt7797790                 0.00           NaN                   NaN
# 2561  tt8665056                 0.00           NaN                   NaN
# 2562  tt8795764                 0.00           NaN                   NaN
# 2563  tt9071078                 0.00           NaN                   NaN
#
#                    budget                           genres  \
# 2559                 0.00   [{'id': 27, 'name': 'Horror'}]
# 2560                 0.00   [{'id': 27, 'name': 'Horror'}]
# 2561                 0.00  [{'id': 37, 'name': 'Western'}]
# 2562                 0.00   [{'id': 27, 'name': 'Horror'}]
# 2563                 0.00   [{'id': 28, 'name': 'Action'}]
#
#                                                homepage                   id  \
# 2559                                                NaN           956,214.00
# 2560                                                NaN           956,219.00
# 2561  http://skeletoncreekproductions.com/p-movie-br...           885,436.00
# 2562  https://www.utahwolf.com/films/coming-soon-new...           871,624.00
# 2563                                                NaN           201,706.00
#
#      original_language                              original_title  ...  \
# 2559                en  Edmund Kemper Part 2: La Mort C'est La Vie  ...
# 2560                en         Edmund Kemper Part 3: La mort sévit  ...
# 2561                en                        Guns Along The Bravo  ...
# 2562                en                                   New Breed  ...
# 2563                cn                                        致命密函  ...
#
#                   revenue              runtime  \
# 2559                 0.00                91.00
# 2560                 0.00                72.00
# 2561                 0.00                85.00
# 2562                 0.00                57.00
# 2563                 0.00                90.00
#
#                                        spoken_languages    status  \
# 2559                                                 []  Released
# 2560  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 2561                                                 []  Released
# 2562  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2563  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
#
#                                                 tagline  \
# 2559                                                NaN
# 2560                                                NaN
# 2561  Evil came to the Southwest until three blazing...
# 2562                                                NaN
# 2563                                                NaN
#
#                                            title                video  \
# 2559  Edmund Kemper Part 2: La Mort C'est La Vie                 0.00
# 2560         Edmund Kemper Part 3: La mort sévit                 0.00
# 2561                        Guns Along The Bravo                 0.00
# 2562                                   New Breed                 0.00
# 2563                              Chinese Heroes                 0.00
#
#              vote_average           vote_count certification
# 2559                 0.00                 0.00           NaN
# 2560                 0.00                 0.00           NaN
# 2561                 0.00                 0.00           NaN
# 2562                 0.00                 0.00            NR
# 2563                 3.00                 2.00           NaN
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2564 entries, 0 to 2563
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2564 non-null   object
#  1   adult                  2562 non-null   float64
#  2   backdrop_path          1394 non-null   object
#  3   belongs_to_collection  205 non-null    object
#  4   budget                 2562 non-null   float64
#  5   genres                 2562 non-null   object
#  6   homepage               173 non-null    object
#  7   id                     2562 non-null   float64
#  8   original_language      2562 non-null   object
#  9   original_title         2562 non-null   object
#  10  overview               2512 non-null   object
#  11  popularity             2562 non-null   float64
#  12  poster_path            2305 non-null   object
#  13  production_companies   2562 non-null   object
#  14  production_countries   2562 non-null   object
#  15  release_date           2544 non-null   object
#  16  revenue                2562 non-null   float64
#  17  runtime                2562 non-null   float64
#  18  spoken_languages       2562 non-null   object
#  19  status                 2562 non-null   object
#  20  tagline                1099 non-null   object
#  21  title                  2562 non-null   object
#  22  video                  2562 non-null   float64
#  23  vote_average           2562 non-null   float64
#  24  vote_count             2562 non-null   float64
#  25  certification          815 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 520.9+ KB

# %%
df.to_csv('Data/tmdb_results_combined.csv.gz',compression='gzip',index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# - Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.

# %%
valid_budget = df[df['budget'] > 0]
valid_revenue = df[df['revenue'] > 0]
valid_financial = pd.concat([valid_budget, valid_revenue])

# %%
sns.displot(data=valid_budget, x='budget')
plt.title('Valid Budget')
plt.xlabel('Budget ($USD)')
plt.show();
print(valid_budget['budget'].describe())
# Out:
# count    5.450000e+02
# mean     2.445237e+07
# std      2.984395e+07
# min      1.000000e+00
# 25%      2.300000e+06
# 50%      1.250000e+07
# 75%      3.500000e+07
# max      1.400000e+08
# Name: budget, dtype: float64

# %%
sns.displot(data=valid_revenue, x='revenue')
plt.title('Valid Revenue')
plt.xlabel('Revenue ($USD)')
plt.show();
print(valid_revenue['revenue'].describe())
# Out:
# count    4.460000e+02
# mean     6.286281e+07
# std      1.120808e+08
# min      1.000000e+00
# 25%      1.270041e+06
# 50%      1.780932e+07
# 75%      7.248453e+07
# max      9.764756e+08
# Name: revenue, dtype: float64

# %%
valid_financial
# Out:
#         imdb_id  adult                     backdrop_path  \
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 6     tt0119273    0.0  /f5C03doOWiauu37bToKXtpgP5bS.jpg
# 11    tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
# 12    tt0120626    0.0  /6xz9H7IMK3W21SNwAVmE9oW6YjX.jpg
# ...         ...    ...                               ...
# 2385  tt0310149    0.0  /qpI3S8hytJzzp5tuLv1t6b7fZ67.jpg
# 2386  tt0310790    0.0  /hAvu0oWrEbbPN71QC8w1NIoUYQT.jpg
# 2456  tt0355857    0.0  /j8Kjy0jiUv3pr7qlEzZXSJRSv1y.jpg
# 2496  tt0445841    0.0  /lO3XAxV38SC7ZuuNVdy6E6nOZac.jpg
# 2514  tt1039952    0.0  /yTGmGjAd0gfpVK0ezoqWgx7AJkp.jpg
#
#                                   belongs_to_collection      budget  \
# 1                                                   NaN  10000000.0
# 4                                                   NaN    150000.0
# 6     {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# 11                                                  NaN    120000.0
# 12                                                  NaN   6105121.0
# ...                                                 ...         ...
# 2385                                                NaN         0.0
# 2386  {'id': 518467, 'name': 'El Bosque Animado', 'p...   3747230.0
# 2456  {'id': 514942, 'name': 'Onmyoji Collection', '...         0.0
# 2496                                                NaN  12500000.0
# 2514                                                NaN    500000.0
#
#                                                  genres homepage        id  \
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN     843.0
# 6     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   16225.0
# 11    [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      NaN   19085.0
# 12    [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...      NaN   54380.0
# ...                                                 ...      ...       ...
# 2385  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...      NaN   17180.0
# 2386                  [{'id': 16, 'name': 'Animation'}]      NaN   49612.0
# 2456  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...      NaN   21325.0
# 2496  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  233308.0
# 2514  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN   69399.0
#
#      original_language     original_title  ...      revenue  runtime  \
# 1                   en    The Fantasticks  ...          0.0     86.0
# 4                   cn               花樣年華  ...   12854953.0     99.0
# 6                   en   Heavy Metal 2000  ...          0.0     88.0
# 11                  en             Vulgar  ...      14904.0     87.0
# 12                  pt  Capitães de Abril  ...          0.0    123.0
# ...                ...                ...  ...          ...      ...
# 2385                ja               修羅雪姫  ...      77567.0     95.0
# 2386                gl   O Bosque Animado  ...     482902.0     83.0
# 2456                ja                陰陽師  ...      16234.0    116.0
# 2496                zh            一個爛賭的傳說  ...  123021750.0     94.0
# 2514                ta          சிட்டிசன்  ...     500000.0    157.0
#
#                                        spoken_languages    status  \
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 6     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 11    [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 12    [{'english_name': 'Portuguese', 'iso_639_1': '...  Released
# ...                                                 ...       ...
# 2385  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 2386  [{'english_name': 'Galician', 'iso_639_1': 'gl...  Released
# 2456  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 2496  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 2514  [{'english_name': 'Tamil', 'iso_639_1': 'ta', ...  Released
#
#                                                 tagline  \
# 1         Try to remember the first time magic happened
# 4     Feel the heat, keep the feeling burning, let t...
# 6     not to survive the fight in the external world...
# 11     Everyone loves a clown... some more than others.
# 12                                                  NaN
# ...                                                 ...
# 2385                                                NaN
# 2386                                                NaN
# 2456                                                NaN
# 2496                                                NaN
# 2514                                                NaN
#
#                              title  video  vote_average vote_count  \
# 1                  The Fantasticks    0.0         5.500       22.0
# 4             In the Mood for Love    0.0         8.114     2191.0
# 6                 Heavy Metal 2000    0.0         6.092      180.0
# 11                          Vulgar    0.0         5.500       44.0
# 12               Captains of April    0.0         6.400       52.0
# ...                            ...    ...           ...        ...
# 2385            The Princess Blade    0.0         5.780       25.0
# 2386             The Living Forest    0.0         5.400       23.0
# 2456  Onmyoji: The Yin Yang Master    0.0         5.775       20.0
# 2496             A Gambler's Story    0.0         6.800        3.0
# 2514                       Citizen    0.0         6.633       15.0
#
#      certification
# 1              NaN
# 4               PG
# 6                R
# 11               R
# 12             NaN
# ...            ...
# 2385           NaN
# 2386            PG
# 2456           NaN
# 2496           NaN
# 2514           NaN
#
# [991 rows x 26 columns]

# %%
valid_financial.describe()
# Out:
#        adult        budget            id  popularity       revenue  \
# count  991.0  9.910000e+02  9.910000e+02  991.000000  9.910000e+02
# mean     0.0  2.567994e+07  4.419526e+04   13.998683  5.631375e+07
# std      0.0  3.071738e+07  1.164964e+05   18.197756  1.080520e+08
# min      0.0  0.000000e+00  1.600000e+01    0.600000  0.000000e+00
# 25%      0.0  1.882374e+06  6.376000e+03    5.259000  1.075565e+05
# 50%      0.0  1.350000e+07  1.147800e+04    9.941000  1.288160e+07
# 75%      0.0  3.900000e+07  3.035500e+04   16.090500  6.441892e+07
# max      0.0  1.400000e+08  1.120809e+06  179.767000  9.764756e+08
#
#           runtime  video  vote_average    vote_count
# count  991.000000  991.0    991.000000    991.000000
# mean   105.714430    0.0      5.908914   1288.317861
# std     21.503023    0.0      1.483794   2722.193503
# min      0.000000    0.0      0.000000      0.000000
# 25%     92.000000    0.0      5.500000     52.000000
# 50%    102.000000    0.0      6.150000    329.000000
# 75%    115.000000    0.0      6.750000   1200.500000
# max    224.000000    0.0     10.000000  24702.000000

# %% [markdown]
# There are 991 movies with valid financial information (budget or revenue over 0).

# %%
budget_and_rev = df[(df['budget'] > 0) & (df['revenue'] > 0)]
budget_and_rev.describe()
# Out:
#        adult        budget             id  popularity       revenue  \
# count  354.0  3.540000e+02     354.000000  354.000000  3.540000e+02
# mean     0.0  3.424372e+07   16759.389831   17.449802  7.844665e+07
# std      0.0  3.202994e+07   29685.997120   20.230565  1.210214e+08
# min      0.0  4.000000e+00      16.000000    0.600000  1.000000e+00
# 25%      0.0  1.000000e+07    2883.250000    9.036000  8.382843e+06
# 50%      0.0  2.400000e+07   10565.500000   12.483500  3.188448e+07
# 75%      0.0  5.000000e+07   16330.000000   18.700250  9.439018e+07
# max      0.0  1.400000e+08  292890.000000  179.767000  9.764756e+08
#
#           runtime  video  vote_average    vote_count
# count  354.000000  354.0    354.000000    354.000000
# mean   108.661017    0.0      6.237593   1756.316384
# std     20.978157    0.0      0.986846   3098.462797
# min     74.000000    0.0      0.000000      0.000000
# 25%     94.000000    0.0      5.760250    182.750000
# 50%    104.500000    0.0      6.307500    596.500000
# 75%    119.000000    0.0      6.809250   1800.750000
# max    224.000000    0.0      8.500000  24702.000000

# %% [markdown]
# There are 354 movies with budget and revenue over 0.

# %% [markdown]
# ## How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
sns.displot(data=budget_and_rev, x='certification')
plt.title('Movies per Certification Category')
plt.xlabel('Certification')
plt.show();
print(budget_and_rev['certification'].value_counts())
# Out:
# R        142
# PG-13    117
# PG        30
# G         13
# NR         7
# Name: certification, dtype: int64

# %% [markdown]
# ## What is the average revenue per certification category?

# %%
avg_rev = budget_and_rev.groupby('certification')['revenue'].mean()

# %%
pd.options.display.float_format = '{:20,.2f}'.format
sns.barplot(data=budget_and_rev, x='certification', y='revenue')
plt.title('Average Revenue per Certification')
plt.xlabel('Certification')
plt.ylabel('Revenue ($USD)')
plt.ticklabel_format(style='plain',
                     axis='y',
                     useOffset=None)
plt.show();
print(avg_rev)
# Out:
# certification
# G             133,216,881.69
# NR             22,122,566.43
# PG            129,080,604.10
# PG-13         111,101,802.32
# R              52,365,899.56
# Name: revenue, dtype: float64

# %% [markdown]
# ## What is the average budget per certification category?

# %%
avg_budg = budget_and_rev.groupby('certification')['budget'].mean()

# %%
sns.barplot(data=budget_and_rev, x='certification', y='budget')
plt.title('Average Budget per Certification')
plt.xlabel('Certification')
plt.ylabel('Budget ($USD)')
plt.ticklabel_format(style='plain',
                     axis='y',
                     useOffset=None)
plt.show();
print(avg_budg)
# Out:
# certification
# G              44,000,000.00
# NR             13,528,571.43
# PG             51,974,907.80
# PG-13          46,627,328.09
# R              26,863,479.23
# Name: budget, dtype: float64
